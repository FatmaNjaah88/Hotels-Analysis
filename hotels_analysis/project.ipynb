# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# EDA & DATA CLEAN

# %%
data=pd.read_csv("hotels.csv")

# %%
data.shape
# Out:
# (119390, 36)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
data['reservation_status_date']=pd.to_datetime(data['reservation_status_date'],format='mixed')

# %%
data['reservation_status_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 119390 entries, 0 to 119389
# Series name: reservation_status_date
# Non-Null Count   Dtype
# --------------   -----
# 119390 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 932.9 KB

# %%
data.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in data.describe(include='object'):
    print(col)
    print(data[col].unique())
    print()
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
#
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data.drop(['company','agent'],axis=1, inplace=True)
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
data['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
data=data[data['adr']<5000]

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
data['adr'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Data Analysis & visualizations

# %%
canceled_percentage=data['is_canceled'].value_counts(normalize=True)
canceled_percentage
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
canceled_percentage=data['is_canceled'].value_counts(normalize=True)
print(canceled_percentage)
plt.figure(figsize=(5,4))
plt.title("Reservation status count")
plt.bar(["Not canceled","canceled"],data['is_canceled'].value_counts(),edgecolor='k',width=.7)
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='hotel',hue='is_canceled',data=data,palette='Pastel1')
plt.title("Calculation rates in city hotel and resort hotel",fontweight='bold',size=18)
plt.show()

# %% [markdown]
# Most booking were in city hotel
# Cancelation in resort hotel is less than city hotel

# %%
city_hotel=data[data['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %%
resort_hotel=data[data['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
resort_hotel=resort_hotel.groupby('reservation_status_date')[['adr']].mean()
resort_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-02                 9.633750
# 2015-01-18                 0.000000
# 2015-01-21                37.301209
# ...                             ...
# 2017-09-08               101.012500
# 2017-09-09               147.778333
# 2017-09-10               145.272500
# 2017-09-12               153.570000
# 2017-09-14               105.930000
#
# [913 rows x 1 columns]

# %%
city_hotel=city_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.063158
# 2015-01-20                76.500000
# 2015-01-30                61.400000
# 2015-02-17                76.500000
# ...                             ...
# 2017-09-03               137.172600
# 2017-09-04               116.925385
# 2017-09-05               154.000000
# 2017-09-06                93.293333
# 2017-09-07               159.685000
#
# [864 rows x 1 columns]

# %%
plt.figure(figsize=(20,8),facecolor='#D4E6F1')
plt.title("Average daily rate in city  and resort hotel ",fontsize=30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label='Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label='City Hotel')
plt.legend(fontsize=20)
plt.show()

# %%
data['month']=data['reservation_status_date'].dt.month
plt.figure(figsize=(15,7),facecolor='#D4E6F1')
sns.countplot(x='month',hue='is_canceled',data=data,palette='Pastel1')
plt.title("Reservation status  per month",fontweight='bold',size=20)
plt.xlabel('month',fontweight='bold',size=15)
plt.ylabel('numder of reservations',fontweight='bold',size=15)
plt.legend(['not canceled','canceled'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per month',size=30)
df=data[data['is_canceled']==1].groupby('month')['adr'].sum().reset_index()
colors = sns.color_palette("husl", len(df))
sns.barplot(x='month',y='adr',data=df,palette=colors)
plt.show()

# %%
canceled_data=data[data['is_canceled']==1]
top_10_country=canceled_data['country'].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title("Top 10 countries with reservation canceled",color='black')
plt.pie(top_10_country,autopct='%.2f',labels=top_10_country.index)
plt.show()

# %%
data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %%
canceled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %%
canceled_df_adr=canceled_data.groupby('reservation_status_date',as_index=False)['adr'].mean()
canceled_df_adr.sort_values('reservation_status_date',inplace=True)

not_canceled_data=data[data['is_canceled']==0]
not_canceled_df_adr=not_canceled_data.groupby('reservation_status_date',as_index=False)['adr'].mean()
not_canceled_df_adr.sort_values('reservation_status_date',inplace=True)
plt.figure(figsize=(20,6),facecolor='#D4E6F1')
plt.title("Average daily rate",size=40,color='black')
plt.plot(not_canceled_df_adr['reservation_status_date'],not_canceled_df_adr['adr'],label='not canceled')
plt.plot(canceled_df_adr['reservation_status_date'],canceled_df_adr['adr'],label='canceled')
plt.legend(fontsize=20)
plt.show()

# %%
canceled_df_adr['reservation_status_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 902 entries, 0 to 901
# Series name: reservation_status_date
# Non-Null Count  Dtype
# --------------  -----
# 902 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.2 KB

# %%
canceled_df_adr = canceled_df_adr[(canceled_df_adr['reservation_status_date'] > '2016-01-01') & 
                                  (canceled_df_adr['reservation_status_date'] < '2017-09-01')]

not_canceled_df_adr = not_canceled_df_adr[(not_canceled_df_adr['reservation_status_date'] > '2016-01-01') & 
                                          (not_canceled_df_adr['reservation_status_date'] < '2017-09-01')]

# %%
plt.figure(figsize=(20,6),facecolor='#D4E6F1')
plt.title("Average daily rate",size=40,color='black')
plt.plot(not_canceled_df_adr['reservation_status_date'],not_canceled_df_adr['adr'],label='not canceled')
plt.plot(canceled_df_adr['reservation_status_date'],canceled_df_adr['adr'],label='canceled')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# I want to know which months are the highest prices for city hotel and resort hotel

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card', 'month'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='arrival_date_month',y='adr',hue='hotel',data=data)
plt.show()

# %% [markdown]
# reseved_room_type
# ['C','A','D','E','G','F','H','L','P','B']
# both hotels have diff room types and diff meal arrangement
# seasonal factors are also important, so the price varies a lot

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "browser"

df = data[data['is_canceled'] == 0]
px.box(data_frame=df, x='reserved_room_type', y='adr', color='hotel',template='plotly_dark')

# %%
df = data[data['is_canceled'] == 0]
sns.boxplot(data=df, x='reserved_room_type', y='adr',hue='hotel')
# Out:
# <Axes: xlabel='reserved_room_type', ylabel='adr'>
